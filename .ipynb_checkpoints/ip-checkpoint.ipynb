# %%
# Install necessary packages
# !pip install chembl_webresource_client pandas scikit-learn seaborn tensorflow torch rdkit xgboost scikit-optimize
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 20.3 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from chembl_webresource_client.new_client import new_client
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from rdkit import Chem
from rdkit.Chem import Descriptors, rdMolDescriptors
from xgboost import XGBRegressor
from skopt import gp_minimize
from skopt.space import Real
from skopt.utils import use_named_args

# %%
# Search for relevant targets
target = new_client.target
target_query = target.search("lipid nanoparticle")
targets_df = pd.DataFrame.from_dict(target_query)

# Select a specific target (e.g., Phospholipid Transfer Protein)
selected_target = "CHEMBL5962"
print(f"Selected Target: {selected_target}")

# Retrieve bioactivity data
activity = new_client.activity
result = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# Convert to DataFrame
df = pd.DataFrame.from_dict(result)
print(f"Bioactivity Data Shape: {df.shape}")

# Save raw data
df.to_csv("bioactivity_data.csv", index=False)
df.head()
# Out:
# Selected Target: CHEMBL5962
# Bioactivity Data Shape: (47, 46)
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      3425190                  []
# 1        None             None      3425191                  []
# 2        None             None      3425192                  []
# 3        None       Not Active      3425193                  []
# 4        None       Not Active      3425194                  []
#
#   assay_chembl_id   assay_description assay_type assay_variant_accession  \
# 0   CHEMBL1228381  Inhibition of PLTP          B                    None
# 1   CHEMBL1228381  Inhibition of PLTP          B                    None
# 2   CHEMBL1228381  Inhibition of PLTP          B                    None
# 3   CHEMBL1228381  Inhibition of PLTP          B                    None
# 4   CHEMBL1228381  Inhibition of PLTP          B                    None
#
#   assay_variant_mutation bao_endpoint  ... target_organism  \
# ...

# %%
# Remove missing values
df = df[df['standard_value'].notna()]
df = df[df['canonical_smiles'].notna()]

# Convert IC50 to pIC50
df['pIC50'] = -np.log10(df['standard_value'].astype(float) * 1e-9)

# Function to compute molecular descriptors
def calculate_descriptors(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        return [
            Descriptors.MolWt(mol),
            Descriptors.MolLogP(mol),
            Descriptors.NumHDonors(mol),
            Descriptors.NumHAcceptors(mol),
            rdMolDescriptors.CalcTPSA(mol),  # Topological Polar Surface Area
            Descriptors.NumRotatableBonds(mol)  # Molecular Flexibility
        ]
    else:
        return [None] * 6

# Apply feature extraction
df[['MolWt', 'LogP', 'HDonors', 'HAcceptors', 'TPSA', 'RotatableBonds']] = df['canonical_smiles'].apply(lambda x: pd.Series(calculate_descriptors(x)))

# Drop NaN values
df.dropna(inplace=True)

# Save processed data
df.to_csv("processed_data.csv", index=False)
print("✅ Data processing completed!")
df.head()
# Out:
# ✅ Data processing completed!
# Empty DataFrame
# Columns: [action_type, activity_comment, activity_id, activity_properties, assay_chembl_id, assay_description, assay_type, assay_variant_accession, assay_variant_mutation, bao_endpoint, bao_format, bao_label, canonical_smiles, data_validity_comment, data_validity_description, document_chembl_id, document_journal, document_year, ligand_efficiency, molecule_chembl_id, molecule_pref_name, parent_molecule_chembl_id, pchembl_value, potential_duplicate, qudt_units, record_id, relation, src_id, standard_flag, standard_relation, standard_text_value, standard_type, standard_units, standard_upper_value, standard_value, target_chembl_id, target_organism, target_pref_name, target_tax_id, text_value, toid, type, units, uo_units, upper_value, value, pIC50, MolWt, LogP, HDonors, HAcceptors, TPSA, RotatableBonds]
# Index: []
#
# [0 rows x 53 columns]

# %%
# Plot pIC50 distribution
plt.figure(figsize=(7, 5))
sns.histplot(df["pIC50"], bins=20, kde=True)
plt.title("pIC50 Value Distribution")
plt.xlabel("pIC50")
plt.ylabel("Frequency")
plt.show()

# %%
print("Bioactivity DataFrame Shape:", df.shape)
print(df.head())
print(df.columns)
# Out:
# Bioactivity DataFrame Shape: (0, 53)
# Empty DataFrame
# Columns: [action_type, activity_comment, activity_id, activity_properties, assay_chembl_id, assay_description, assay_type, assay_variant_accession, assay_variant_mutation, bao_endpoint, bao_format, bao_label, canonical_smiles, data_validity_comment, data_validity_description, document_chembl_id, document_journal, document_year, ligand_efficiency, molecule_chembl_id, molecule_pref_name, parent_molecule_chembl_id, pchembl_value, potential_duplicate, qudt_units, record_id, relation, src_id, standard_flag, standard_relation, standard_text_value, standard_type, standard_units, standard_upper_value, standard_value, target_chembl_id, target_organism, target_pref_name, target_tax_id, text_value, toid, type, units, uo_units, upper_value, value, pIC50, MolWt, LogP, HDonors, HAcceptors, TPSA, RotatableBonds]
# Index: []
#
# [0 rows x 53 columns]
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
# ...

# %%
# Retrieve all bioactivity data for the selected target
result = activity.filter(target_chembl_id=selected_target)

# Convert to DataFrame
df_raw = pd.DataFrame.from_dict(result)

# Print available columns
print(df_raw.columns)
# Out:
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %%
# Check if the column has any non-null values
print("Unique standard_type values:", df_raw["standard_type"].dropna().unique())
# Out:
# Unique standard_type values: ['Activity' 'IC50' 'Inhibition']

# %%
print(targets_df[['pref_name', 'target_chembl_id']])
# Out:
#                                              pref_name target_chembl_id
# 0                                        Lipid bilayer    CHEMBL4651323
# 1                        Phospholipid transfer protein       CHEMBL5962
# 2                             Glycosyltransferase WbpZ    CHEMBL2390815
# 3                   Acylglycerol kinase, mitochondrial    CHEMBL2417354
# 4                   Cholesteryl ester transfer protein       CHEMBL3572
# ..                                                 ...              ...
# 181                   Lysophosphatidic acid receptor 2    CHEMBL4523464
# 182                               Prkaa1/Prkab2/Prkag1    CHEMBL4523617
# 183  12-(S)-hydroxy-5,8,10,14-eicosatetraenoic acid...    CHEMBL4523859
# 184                                          VHL/GPER1    CHEMBL5169075
# 185                                     GPR40-Galpha16    CHEMBL5482994
#
# [186 rows x 2 columns]
